# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('OttawaSelect.csv', encoding='latin1')

df.head(5)
# Out:
#                                                 name  \
# 0                   Westboro Village Executive Suite
# 1                      Rural charm close to the city
# 2                  Basement Studio - Old Ottawa East
# 3  Private entrance apartment, 3-bdrm - up to 8 g...
# 4                Adorable 2 bdrm, Central Ottawa PD1
#
#                                          description  \
# 0  A tastefully decorated and well equipped upper...
# 1  Close to Strathmere and other wedding venues. ...
# 2                                                NaN
# 3  GREAT for a family or a group. The apt. is low...
# 4  This an adorable property with two bedrooms, f...
#
#                                neighborhood_overview         host_name  \
# 0  Westboro Village is a century-old community, a...             Glenn
# 1  Most folks ask about Strathmere - we are less ...            Daniel
# 2  The worlds longest skating rink, a UNESCO heri...               Ela
# ...

# %%
#Copia del dataset
df1 = df.copy()
df1
# Out:
#                                                    name  \
# 0                      Westboro Village Executive Suite
# 1                         Rural charm close to the city
# 2                     Basement Studio - Old Ottawa East
# 3     Private entrance apartment, 3-bdrm - up to 8 g...
# 4                   Adorable 2 bdrm, Central Ottawa PD1
# ...                                                 ...
# 2859               Tina's Place walk to Parliament Hill
# 2860                            Cozy Two bedrooms Condo
# 2861                       Corporate Suite - Centertown
# 2862                    Charming Room in Quiet Location
# 2863                       Master bed room in Barrhaven
#
#                                             description  \
# 0     A tastefully decorated and well equipped upper...
# 1     Close to Strathmere and other wedding venues. ...
# 2                                                   NaN
# 3     GREAT for a family or a group. The apt. is low...
# ...

# %%
#Recuento de los valores nulos del dataframe
nulos = df1.isnull().sum()
nulos = nulos[nulos > 0]
nulos
# Out:
# description                       51
# neighborhood_overview           1522
# host_location                    631
# host_response_time               370
# host_response_rate               370
# host_acceptance_rate             300
# host_is_superhost                129
# host_neighbourhood              1639
# neighbourhood                   1522
# neighbourhood_group_cleansed    2864
# bathrooms_text                     2
# bedrooms                          61
# beds                             216
# price                            215
# has_availability                  27
# first_review                     511
# last_review                      511
# review_scores_rating             511
# review_scores_accuracy           511
# review_scores_cleanliness        511
# review_scores_checkin            511
# review_scores_communication      511
# review_scores_location           511
# review_scores_value              511
# reviews_per_month                511
# dtype: int64

# %%
#ELIMINACIÓN DE COLUMNA
#Se hizo la eliminación de una columna, ya que todos los registros de esa columna estaban vacíos
df2 = df1.drop(['neighbourhood_group_cleansed'], axis =1)

#Recuento de los valores nulos del dataframe
nulos = df2.isnull().sum()
nulos = nulos[nulos > 0]
nulos
# Out:
# description                      51
# neighborhood_overview          1522
# host_location                   631
# host_response_time              370
# host_response_rate              370
# host_acceptance_rate            300
# host_is_superhost               129
# host_neighbourhood             1639
# neighbourhood                  1522
# bathrooms_text                    2
# bedrooms                         61
# beds                            216
# price                           215
# has_availability                 27
# first_review                    511
# last_review                     511
# review_scores_rating            511
# review_scores_accuracy          511
# review_scores_cleanliness       511
# review_scores_checkin           511
# review_scores_communication     511
# review_scores_location          511
# review_scores_value             511
# reviews_per_month               511
# dtype: int64

# %% [markdown]
# **SUSTITUCIÓN DE VALORES NULOS DEL DATAFRAME**

# %%
#PRIMER MÉTODO DE SUSTITUCIÓN 
#Sustitución de valores nulos por uno string concreto

df2["description"] = df2["description"].fillna("pending description")
df2["neighborhood_overview"] = df2["neighborhood_overview"].fillna("pending description")
df2["host_is_superhost"] = df2["host_is_superhost"].fillna("f")
df2["host_location"] = df2["host_location"].fillna("No location")
df2["neighbourhood"] = df2["neighbourhood"].fillna("Neighborhood highlights")
df2["bathrooms_text"]=df2["bathrooms_text"].fillna("1 bath")
df2["price"]=df2["price"].fillna("$100.00")
df2["host_neighbourhood"]=df2["host_neighbourhood"].fillna("No location")



nulos = df2.isnull().sum()
nulos = nulos[nulos > 0]
nulos
# Out:
# host_response_time             370
# host_response_rate             370
# host_acceptance_rate           300
# bedrooms                        61
# beds                           216
# has_availability                27
# first_review                   511
# last_review                    511
# review_scores_rating           511
# review_scores_accuracy         511
# review_scores_cleanliness      511
# review_scores_checkin          511
# review_scores_communication    511
# review_scores_location         511
# review_scores_value            511
# reviews_per_month              511
# dtype: int64

# %%
#SEGUNDO MÉTODO DE SUSUTITUCIÓN
#Susitución de valores nulos por valores no nulos hacia adelante
columnas_nulas = ["host_response_time", "host_response_rate", "host_acceptance_rate"]

for columna in columnas_nulas:
    if columna in df2.columns:
        df2[columna].fillna(method="ffill", inplace=True)

#Comprobamos valores nulos
nulos = df2.isnull().sum()
nulos = nulos[nulos > 0]
nulos
# Out:
# C:\Users\aresm\AppData\Local\Temp\ipykernel_23408\3872259780.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2[columna].fillna(method="ffill", inplace=True)
# C:\Users\aresm\AppData\Local\Temp\ipykernel_23408\3872259780.py:7: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2[columna].fillna(method="ffill", inplace=True)
# bedrooms                        61
# beds                           216
# ...

# %%
#TERCER MÉTODO DE SUSUTITUCIÓN
#Sustitución de valores nulos por valores calculados por medio del promedio. 
columnas_nulas = ["review_scores_rating", "reviews_per_month", "review_scores_accuracy", "review_scores_cleanliness", "review_scores_checkin", "review_scores_communication", "review_scores_location", "review_scores_value"]

for columna in columnas_nulas:
    if columna in df2.columns:
        df2[columna].fillna(df2[columna].mean(), inplace=True)

nulos = df2.isnull().sum()
nulos = nulos[nulos > 0]
nulos
# Out:
# C:\Users\aresm\AppData\Local\Temp\ipykernel_23408\2083669382.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2[columna].fillna(df2[columna].mean(), inplace=True)
# bedrooms             61
# beds                216
# has_availability     27
# first_review        511
# last_review         511
# dtype: int64

# %%
#CUARTO MÉTODO DE SUSTITUCIÓN 
#Sustitución de valores nulos por un numero específico.

df2["bedrooms"]=df2["bedrooms"].fillna(1)
df2["beds"]=df2["beds"].fillna(1)
df2["first_review"]=df2["first_review"].fillna(10)
df2["last_review"]=df2["last_review"].fillna(10)

nulos=df2.isnull().sum()
nulos = nulos[nulos > 0]
nulos
# Out:
# has_availability    27
# dtype: int64

# %%
#QUINTO MÉTODO DE SUSUTITUCIÓN
#Susitución de valores nulos por valores no nulos hacia atrás

df2["has_availability"]=df2["has_availability"].fillna(method="bfill")

nulos=df2.isnull().sum()
nulos = nulos[nulos > 0]
nulos
# Out:
# C:\Users\aresm\AppData\Local\Temp\ipykernel_23408\2003161875.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2["has_availability"]=df2["has_availability"].fillna(method="bfill")
# Series([], dtype: int64)

# %%
#IMPORTAR CSV CON LOS VALORES FINALES
df2.to_csv("OttawaSinNulos1.csv")
